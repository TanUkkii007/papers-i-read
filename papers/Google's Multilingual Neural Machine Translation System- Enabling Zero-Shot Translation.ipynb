# %% [markdown]
# # Google’s Multilingual Neural Machine Translation System: Enabling Zero-Shot Translation
#
# Link:　https://arxiv.org/abs/1611.04558
#
# Authors:　Melvin Johnson, Mike Schuster, Quoc V. Le, Maxim Krikun, Yonghui Wu, Zhifeng Chen, Nikhil Thorat, Fernanda Viégas, Martin Wattenberg, Greg Corrado, Macdu Hughes, Jeffrey Dean
#
# Institution: Google
#
# Publication: arXiv
#
# Date: 2016

# %% [markdown]
# ## Background Materials

# %% [markdown]
# ## Papers citing this paper

# %% [markdown]
# ## What is this paper about?

# %% [markdown]
# ## What is the motivation of this research?

# %% [markdown]
# ## What makes this paper different from previous research?

# %% [markdown]
# ## How this paper achieve it?

# %% [markdown]
# ## Dataset used in this study

# %% [markdown]
# ## Implementations

# %% [markdown]
# ## Further Readings
